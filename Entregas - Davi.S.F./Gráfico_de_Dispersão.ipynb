# %% [markdown]
# <a href="https://colab.research.google.com/github/sfDavi/iec2023_1_AeB/blob/main/Gr%C3%A1fico_de_Dispers%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gráficos de dispersão com Seaborn

# %% [markdown]
# ## Importação das bibliotecas

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ## Carregamento da base de dados

# %%
dataset = pd.read_csv('plano_saude.csv', encoding='ISO-8859–1')
#utilizando encoding, sem isto estava dando erro

# %%
dataset
# Out:
#    Idade  custo genero fumante  tamanho  Unnamed: 5
# 0     18    871      M     Sim        1         NaN
# 1     23   1132      M     No        2         NaN
# 2     28   1242      F     Sim        3         NaN
# 3     33   1356      F     Sim        2         NaN
# 4     38   1488      M     No        1         NaN
# 5     43   1638      F     No        3         NaN
# 6     48   2130      M     No        1         NaN
# 7     53   2454      F     Sim        2         NaN
# 8     58   3066      F     No        3         NaN
# 9     63   4090      F     Sim        2         NaN

# %% [markdown]
# ## Gráficos de dispersão

# %%
#anteriormente Idade estava com i minúsculo, no arquivo utilizado pelo professor está em maiúsculo, por isso mudei
sns.relplot(x="custo", y="Idade", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", hue="genero", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", hue="genero", style="genero", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", hue="genero", style="fumante", data=dataset);
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/utils.py:80: UserWarning: Glyph 139 (\x8b) missing from current font.
#   fig.canvas.draw()
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 139 (\x8b) missing from current font.
#   func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 139 (\x8b) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.relplot(x="custo", y="Idade", hue="tamanho", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", size="tamanho", data=dataset);

# %%
sns.relplot(x="custo", y="Idade", size="tamanho", sizes=(15, 200), data=dataset);
