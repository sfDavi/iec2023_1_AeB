# %% [markdown]
# <a href="https://colab.research.google.com/github/scadriano/iec2023_1_AeB/blob/main/01.%20Conceitua%C3%A7%C3%A3o%20de%20Python%20/%20Aula_08_Bye%2C_bye_World!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Introdução à Engenharia de Computação

# %%
from platform import python_version
print(f'A versão em uso é {python_version()}.')
# Out:
# A versão em uso é 3.10.12.

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %% [markdown]
# # Operadores Aritméticos

# %%
# Adição
1 + 1
# Out:
# 2

# %%
# Subtração
2 - 1

# %%
# Multiplicação
2 * 2

# %%
# Divisão
3 / 2

# %%
# Potência
4 ** 2

# %%
# Módulo (resto da divisão)
10 % 3
# Out:
# 1

# %% [markdown]
# # Tipo de Dados (Type)

# %%
# Qual o tipo do (?) -> Inteiro
type(5)
# Out:
# int

# %%
# Qual o tipo do (?) -> Float - Decimal
type(5.0)
# Out:
# float

# %%
# Qual o tipo do (?) -> String
a = 'Estudando Python!'
type(a)
# Out:
# str

# %% [markdown]
# # Condicional if

# %%
# Condicional if (Se)
if 5 > 2:
    print("A sentença é verdadeira!")
# Out:
# A sentença é verdadeira!

# %%
# Condicional if...else
if 5 < 2:
    print("A sentença é verdadeira!")
else:
    print("A sentença é falsa!")
# Out:
# A sentença é falsa!

# %%
# Condicional if...else com variável
dia = "Quarta-feira"
if dia == "Sexta-feira":
    print("Hoje fará sol!")
else:
    print("Hoje vai chover!")

type(dia)
# Out:
# Hoje vai chover!
# str

# %% [markdown]
# # Manipulando arquivos

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Lendo arquivos (.txt)

# %%
# Abrindo o arquivo para leitura
a1 = open("/content/drive/MyDrive/Colab Notebooks/Aula 3 - Bye, bye World!/arquivos/arquivo1.txt", "r")

# %%
# Lendo o arquivo
print(a1.read())
# Out:
# Olá, aula de projetos de IA - 03_05!

# %% [markdown]
# ### Gravando arquivos (.txt)

# %%
# Abrindo o arquivo para gravação
a2 = open("/content/drive/MyDrive/Colab Notebooks/Aula 3 - Bye, bye World!/arquivos/arquivo2.txt", "w")

# %%
# Gravando no arquivo
a2.write("Arraial do Engenho - 2023!")
# Out:
# 26

# %%
# Abrindo o arquivo para leitura
a2 = open("/content/drive/MyDrive/Colab Notebooks/Aula 3 - Bye, bye World!/arquivos/arquivo2.txt", "r")

# %%
# Imprimindo arquivo
print(a2.read())
# Out:
# Arraial do Engenho - 2023!
